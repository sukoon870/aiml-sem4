# %%
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='localhost', database='aiml', user='root', password='root')
# db_cursor = db_connection.cursor()
# db_cursor.execute('SELECT * FROM customers')
# table_rows = db_cursor.fetchall()
# df = pd.DataFrame(table_rows)
df = pd.read_sql('SELECT * FROM train', con=db_connection)
df
# Out:
# C:\Users\sukoo\AppData\Local\Temp\ipykernel_20836\2900932634.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('SELECT * FROM train', con=db_connection)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# ...

# %% [markdown]
# # DISPLAY TOP 5 ROWS OF THE DATASET

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500              S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250              S

# %% [markdown]
# # CHECK LAST 3 ROWS OF THE DATASET

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  Age  \
# 711          888         1       1  Graham, Miss. Margaret Edith  female   19
# 712          890         1       1         Behr, Mr. Karl Howell    male   26
# 713          891         0       3           Dooley, Mr. Patrick    male   32
#
#      SibSp  Parch  Ticket   Fare Cabin Embarked
# 711      0      0  112053  30.00   B42        S
# 712      0      0  111369  30.00  C148        C
# 713      0      0  370376   7.75              Q

# %% [markdown]
# # FIND SHAPE OF OUR DATASET(NUMBER OF ROWS & NUMBER OF COLUMNS)

# %%
df.shape
# Out:
# (714, 12)

# %% [markdown]
# # GET INFORMATION ABOUT OUR DATASET LIKE TOTAL NUMBER ROWS,TOTAL NUMBER OF COLUMNS,DATATYPE OF EACH COLUMN AND MEMORY REQUIREDMENT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  714 non-null    int64
#  1   Survived     714 non-null    int64
#  2   Pclass       714 non-null    int64
#  3   Name         714 non-null    object
#  4   Sex          714 non-null    object
#  5   Age          714 non-null    int64
#  6   SibSp        714 non-null    int64
#  7   Parch        714 non-null    int64
#  8   Ticket       714 non-null    object
#  9   Fare         714 non-null    float64
#  10  Cabin        714 non-null    object
#  11  Embarked     714 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 67.1+ KB

# %% [markdown]
# # GET OVERALL STATISTICS ABOUT THE DATAFRAME

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   714.000000  714.000000  714.000000  714.000000  714.000000
# mean    448.582633    0.406162    2.236695   29.712885    0.512605
# std     259.119524    0.491460    0.838250   14.529273    0.929783
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     222.250000    0.000000    1.000000   20.250000    0.000000
# 50%     445.000000    0.000000    2.000000   28.000000    0.000000
# 75%     677.750000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  714.000000  714.000000
# mean     0.431373   34.694514
# std      0.853289   52.918930
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.741700
# 75%      1.000000   33.375000
# max      6.000000  512.329200

# %% [markdown]
# # DATA FILTERING

# %%
df.filter(items=['Age', 'Fare'])
# Out:
#      Age     Fare
# 0     22   7.2500
# 1     38  71.2833
# 2     26   7.9250
# 3     35  53.1000
# 4     35   8.0500
# ..   ...      ...
# 709   39  29.1250
# 710   27  13.0000
# 711   19  30.0000
# 712   26  30.0000
# 713   32   7.7500
#
# [714 rows x 2 columns]

# %% [markdown]
# # CHECK NULL VALUES IN THE DATASET

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # DROP THE COLUMN

# %%
df.drop(["Name"], axis=1)
# Out:
#      PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch  \
# 0              1         0       3    male   22      1      0
# 1              2         1       1  female   38      1      0
# 2              3         1       3  female   26      0      0
# 3              4         1       1  female   35      1      0
# 4              5         0       3    male   35      0      0
# ..           ...       ...     ...     ...  ...    ...    ...
# 709          886         0       3  female   39      0      5
# 710          887         0       2    male   27      0      0
# 711          888         1       1  female   19      0      0
# 712          890         1       1    male   26      0      0
# 713          891         0       3    male   32      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500              S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250              S
# ...

# %% [markdown]
# # HANDLE MISSING VALUES

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %% [markdown]
# # CATEGORICAL DATA ENCODING

# %%
# encoding textual data into number for easier processing in algorithms
df2 = df.copy();
print(df2["Sex"].unique())
df2["Sex"] = df2["Sex"].replace({'male':1,'female':0})
df2
# Out:
# ['male' 'female']
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name  Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0   38      1
# 2                               Heikkinen, Miss. Laina    0   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0   35      1
# 4                             Allen, Mr. William Henry    1   35      0
# ..                                                 ...  ...  ...    ...
# ...

# %% [markdown]
# # WHAT IS UNIVARIATE ANALYSIS

# %% [markdown]
# Each variable in the dataset is explored separably

# %% [markdown]
# # HOW MANY PEOPLE SURVIVED AND HOW MANY DIED PLOT ON GRAPH

# %%
df['Survived'].replace({0:"Dead",1:"Alive"}).value_counts().plot(kind='bar',rot=0)
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# # HOW MANY PASSENGERS WERE IN FIRST CLASS,SECOND CLASS AND THIRD CLASS PLOT THOSE FIGURES ON GRAPH

# %%
df["Pclass"].replace({1:"First",2:"Second",3:"Third"}).value_counts().plot(kind='bar',rot=0,xlabel="Class")
# Out:
# <Axes: xlabel='Class'>

# %% [markdown]
# # NUMBER  OF MALE AND FEMALE PASSANGERS

# %%
df["Sex"].value_counts().plot(kind='bar',rot=0)
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# # BIVARIANT ANALSIS

# %% [markdown]
# Two variables are observed

# %% [markdown]
# # WHO HAS BETTER CANCE OF SURVIVAL MALE OR FEMALE

# %%
_df = df.replace({"Survived":{0:"Dead",1:"Alive"}})
_df.groupby(["Survived","Sex"]).size().unstack().plot(kind='bar',stacked=True,rot=0)
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# # WHICH PASSENGER CLASS HAS BETTER CHANCE OF SURVIVAL(FIRST,SECOND,OR THIRD CLASS)?

# %%
_df.groupby(["Survived","Pclass"]).size().unstack().plot(kind='bar',stacked=True,rot=0)
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# # FEATURE ENGINEERING

# %% [markdown]
# Process of transforming raw data into that is suitable for machine learning models
